# %%
import pandas as pd

# %%
data = pd.read_csv('Documentos/UDELAR/logs/bio/logs_Bioquímica I 2018_20191015-1713.csv')

# %%
data
# Out:
#                   Time   User full name  Affected user  \
# 0      15/10/19, 17:13  Analista Moodle              -
# 1      15/10/19, 17:13  Analista Moodle              -
# 2       1/10/19, 12:18  Analista Moodle              -
# 3       1/10/19, 12:17  Analista Moodle              -
# 4       1/10/19, 12:17  Analista Moodle              -
# ...                ...              ...            ...
# 89132  14/02/18, 13:43   Garófalo Lucía  Susana Castro
# 89133  14/02/18, 13:43   Garófalo Lucía              -
# 89134  14/02/18, 13:43   Garófalo Lucía              -
# 89135  14/02/18, 13:43   Garófalo Lucía              -
# 89136  14/02/18, 13:43   Garófalo Lucía              -
#
#                    Event context Component                  Event name  \
# 0      Course: Bioquímica I 2018      Logs           Log report viewed
# 1      Course: Bioquímica I 2018    System               Course viewed
# 2      Course: Bioquímica I 2018    System            User list viewed
# ...
