# %%
import numpy as np
import pandas as pd

# %%
nomeArq = 'TypeWeeksIntlogs_Teoría del cine_20191015-1206.csv'

# %%
codDisciplina = 7220

# %%
caminho = "~/Documentos/UDELAR/logs/fic/"

# %%
read = caminho + nomeArq

# %%
moodle = pd.read_csv(read)

# %%
print(read)
# Out:
# ~/Documentos/UDELAR/logs/fic/TypeWeeksIntlogs_Teoría del cine_20191015-1206.csv

# %%
resultadoxcenso = pd.read_csv('Documentos/UDELAR/6.0_RESULTADOxCENSO_varsNovo.csv', low_memory=False)

# %%
#resultadoxcenso.tail

# %%
#só na primeira vez que rodar o script
#resultadoxcenso['Folder Week 2'] = 0
#resultadoxcenso['Folder Week 4'] = 0
#resultadoxcenso['Folder Week 6'] = 0
#resultadoxcenso['Folder Week 8'] = 0
#resultadoxcenso['Folder Week 10'] = 0
#resultadoxcenso['Folder Week 12'] = 0
#resultadoxcenso['Folder Week 14'] = 0
#resultadoxcenso['Folder Week 16'] = 0

#resultadoxcenso['Forum Week 2'] = 0
#resultadoxcenso['Forum Week 4'] = 0
#resultadoxcenso['Forum Week 6'] = 0
#resultadoxcenso['Forum Week 8'] = 0
#resultadoxcenso['Forum Week 10'] = 0
#resultadoxcenso['Forum Week 12'] = 0
#resultadoxcenso['Forum Week 14'] = 0
#resultadoxcenso['Forum Week 16'] = 0

#resultadoxcenso['Page Week 2'] = 0
#resultadoxcenso['Page Week 4'] = 0
#resultadoxcenso['Page Week 6'] = 0
#resultadoxcenso['Page Week 8'] = 0
#resultadoxcenso['Page Week 10'] = 0
#resultadoxcenso['Page Week 12'] = 0
#resultadoxcenso['Page Week 14'] = 0
#resultadoxcenso['Page Week 16'] = 0

#resultadoxcenso['Quiz Week 2'] = 0
#resultadoxcenso['Quiz Week 4'] = 0
#resultadoxcenso['Quiz Week 6'] = 0
#resultadoxcenso['Quiz Week 8'] = 0
#resultadoxcenso['Quiz Week 10'] = 0
#resultadoxcenso['Quiz Week 12'] = 0
#resultadoxcenso['Quiz Week 14'] = 0
#resultadoxcenso['Quiz Week 16'] = 0

#resultadoxcenso['URL Week 2'] = 0
#resultadoxcenso['URL Week 4'] = 0
#resultadoxcenso['URL Week 6'] = 0
#resultadoxcenso['URL Week 8'] = 0
#resultadoxcenso['URL Week 10'] = 0
#resultadoxcenso['URL Week 12'] = 0
#resultadoxcenso['URL Week 14'] = 0
#resultadoxcenso['URL Week 16'] = 0

# %%
#list(resultadoxcenso)

# %%
list(moodle)
# Out:
# ['Description', 'Component', '0', '1', '2', '3', '4', '5', '6', '7']

# %%
for index, row in resultadoxcenso.iterrows():
    #id_moodle = row['Description']
    #temp = int(row['codigo_persona'])
    if int(row['codigo_mat']) == codDisciplina:
        print('index = ' + str(index) )
        
        #busca = "Description == '" + str(row['Id_moodle'])+ "' and Component = 'Folder'"
        folder = "Description == '" + str(row['Id_moodle'])+ "'" + " & Component == 'Folder'"
        forum = "Description == '" + str(row['Id_moodle'])+ "' & Component == 'Forum'"
        page = "Description == '" + str(row['Id_moodle'])+ "' & Component == 'Page'"
        quiz = "Description == '" + str(row['Id_moodle'])+ "' & Component == 'Quiz'"
        url = "Description == '" + str(row['Id_moodle'])+ "' & Component == 'URL'"
        #print(folder)
        interFolder0 = moodle.query(folder)[['0']].values
        interFolder1 = moodle.query(folder)[['1']].values
        interFolder2 = moodle.query(folder)[['2']].values
        interFolder3 = moodle.query(folder)[['3']].values
        interFolder4 = moodle.query(folder)[['4']].values
        interFolder5 = moodle.query(folder)[['5']].values
        interFolder6 = moodle.query(folder)[['6']].values
        interFolder7 = moodle.query(folder)[['7']].values
        
        interForum0 = moodle.query(forum)[['0']].values
        interForum1 = moodle.query(forum)[['1']].values
        interForum2 = moodle.query(forum)[['2']].values
        interForum3 = moodle.query(forum)[['3']].values
        interForum4 = moodle.query(forum)[['4']].values
        interForum5 = moodle.query(forum)[['5']].values
        interForum6 = moodle.query(forum)[['6']].values
        interForum7 = moodle.query(forum)[['7']].values
        
        interPage0 = moodle.query(page)[['0']].values
        interPage1 = moodle.query(page)[['1']].values
        interPage2 = moodle.query(page)[['2']].values
        interPage3 = moodle.query(page)[['3']].values
        interPage4 = moodle.query(page)[['4']].values
        interPage5 = moodle.query(page)[['5']].values
        interPage6 = moodle.query(page)[['6']].values
        interPage7 = moodle.query(page)[['7']].values
        
        interQuiz0 = moodle.query(quiz)[['0']].values
        interQuiz1 = moodle.query(quiz)[['1']].values
        interQuiz2 = moodle.query(quiz)[['2']].values
        interQuiz3 = moodle.query(quiz)[['3']].values
        interQuiz4 = moodle.query(quiz)[['4']].values
        interQuiz5 = moodle.query(quiz)[['5']].values
        interQuiz6 = moodle.query(quiz)[['6']].values
        interQuiz7 = moodle.query(quiz)[['7']].values
    
        interURL0 = moodle.query(url)[['0']].values      
        interURL1 = moodle.query(url)[['1']].values
        interURL2 = moodle.query(url)[['2']].values
        interURL3 = moodle.query(url)[['3']].values
        interURL4 = moodle.query(url)[['4']].values
        interURL5 = moodle.query(url)[['5']].values
        interURL6 = moodle.query(url)[['6']].values
        interURL7 = moodle.query(url)[['7']].values
        
        interFolder0 = str(interFolder0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder1 = str(interFolder1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder2 = str(interFolder2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder3 = str(interFolder3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder4 = str(interFolder4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder5 = str(interFolder5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder6 = str(interFolder6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder7 = str(interFolder7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        interForum0 = str(interForum0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum1 = str(interForum1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum2 = str(interForum2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum3 = str(interForum3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum4 = str(interForum4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum5 = str(interForum5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum6 = str(interForum6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum7 = str(interForum7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        interPage0 = str(interPage0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage1 = str(interPage1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage2 = str(interPage2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage3 = str(interPage3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage4 = str(interPage4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage5 = str(interPage5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage6 = str(interPage6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage7 = str(interPage7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        interQuiz0 = str(interQuiz0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz1 = str(interQuiz1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz2 = str(interQuiz2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz3 = str(interQuiz3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz4 = str(interQuiz4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz5 = str(interQuiz5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz6 = str(interQuiz6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz7 = str(interQuiz7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        interURL0 = str(interURL0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL1 = str(interURL1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL2 = str(interURL2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL3 = str(interURL3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL4 = str(interURL4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL5 = str(interURL5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL6 = str(interURL6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL7 = str(interURL7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        #print(interFolder)
        #print(interForum)
        #print(interPage)
        #print(interQuiz)
        #print(interURL)
        resultadoxcenso.loc[index, 'Folder Week 2'] = interFolder0
        resultadoxcenso.loc[index, 'Folder Week 4'] = interFolder1
        resultadoxcenso.loc[index, 'Folder Week 6'] = interFolder2
        resultadoxcenso.loc[index, 'Folder Week 8'] = interFolder3
        resultadoxcenso.loc[index, 'Folder Week 10'] = interFolder4
        resultadoxcenso.loc[index, 'Folder Week 12'] = interFolder5
        resultadoxcenso.loc[index, 'Folder Week 14'] = interFolder6
        resultadoxcenso.loc[index, 'Folder Week 16'] = interFolder7
        
        resultadoxcenso.loc[index, 'Forum Week 2'] = interForum0
        resultadoxcenso.loc[index, 'Forum Week 4'] = interForum1
        resultadoxcenso.loc[index, 'Forum Week 6'] = interForum2
        resultadoxcenso.loc[index, 'Forum Week 8'] = interForum3
        resultadoxcenso.loc[index, 'Forum Week 10'] = interForum4
        resultadoxcenso.loc[index, 'Forum Week 12'] = interForum5
        resultadoxcenso.loc[index, 'Forum Week 14'] = interForum6
        resultadoxcenso.loc[index, 'Forum Week 16'] = interForum7
        
        resultadoxcenso.loc[index, 'Page Week 2'] = interPage0
        resultadoxcenso.loc[index, 'Page Week 4'] = interPage1
        resultadoxcenso.loc[index, 'Page Week 6'] = interPage2
        resultadoxcenso.loc[index, 'Page Week 8'] = interPage3
        resultadoxcenso.loc[index, 'Page Week 10'] = interPage4
        resultadoxcenso.loc[index, 'Page Week 12'] = interPage5
        resultadoxcenso.loc[index, 'Page Week 14'] = interPage6
        resultadoxcenso.loc[index, 'Page Week 16'] = interPage7
        
        resultadoxcenso.loc[index, 'Quiz Week 2'] = interQuiz0
        resultadoxcenso.loc[index, 'Quiz Week 4'] = interQuiz1
        resultadoxcenso.loc[index, 'Quiz Week 6'] = interQuiz2
        resultadoxcenso.loc[index, 'Quiz Week 8'] = interQuiz3
        resultadoxcenso.loc[index, 'Quiz Week 10'] = interQuiz4
        resultadoxcenso.loc[index, 'Quiz Week 12'] = interQuiz5
        resultadoxcenso.loc[index, 'Quiz Week 14'] = interQuiz6
        resultadoxcenso.loc[index, 'Quiz Week 16'] = interQuiz7
        
        resultadoxcenso.loc[index, 'URL Week 2'] = interURL0
        resultadoxcenso.loc[index, 'URL Week 4'] = interURL1
        resultadoxcenso.loc[index, 'URL Week 6'] = interURL2
        resultadoxcenso.loc[index, 'URL Week 8'] = interURL3
        resultadoxcenso.loc[index, 'URL Week 10'] = interURL4
        resultadoxcenso.loc[index, 'URL Week 12'] = interURL5
        resultadoxcenso.loc[index, 'URL Week 14'] = interURL6
        resultadoxcenso.loc[index, 'URL Week 16'] = interURL7
        
    #print(temp)
# Out:
# index = 14
# index = 303
# index = 343
# index = 823
# index = 869
# index = 1059
# index = 1217
# index = 1225
# index = 1249
# index = 1441
# index = 1844
# index = 1948
# index = 1971
# index = 2119
# index = 2174
# index = 2227
# index = 2268
# index = 2406
# index = 2411
# index = 2548
# index = 2621
# index = 2624
# index = 2676
# index = 2694
# index = 2745
# index = 2758
# index = 2903
# index = 3059
# index = 3085
# index = 3127
# index = 3136
# index = 3208
# index = 3238
# index = 3271
# index = 3306
# index = 3324
# index = 3339
# index = 3378
# index = 3445
# index = 3587
# index = 3631
# index = 3654
# index = 3749
# index = 3815
# index = 3822
# index = 4019
# index = 4093
# index = 4157
# index = 4213
# index = 4220
# index = 4353
# index = 4388
# index = 4510
# index = 4798
# index = 4971
# index = 5062
# index = 5713
# index = 5714
# index = 5750

# %%
for index, row in resultadoxcenso.iterrows():
    #id_moodle = row['Description']
    #temp = int(row['codigo_persona'])
    if int(row['codigo_mat']) == codDisciplina:
        print('index = ' + str(index) )
        
        #busca = "Description == '" + str(row['Id_moodle'])+ "' and Component = 'Folder'"
        folder = "Description == '" + str(row['Id_moodle'])+ "'" + " & Component == 'Folder'"
        forum = "Description == '" + str(row['Id_moodle'])+ "' & Component == 'Forum'"
        page = "Description == '" + str(row['Id_moodle'])+ "' & Component == 'Page'"
        quiz = "Description == '" + str(row['Id_moodle'])+ "' & Component == 'Quiz'"
        url = "Description == '" + str(row['Id_moodle'])+ "' & Component == 'URL'"
        #print(folder)
        interFolder0 = moodle.query(folder)[['0']].values
        interFolder1 = moodle.query(folder)[['1']].values
        interFolder2 = moodle.query(folder)[['2']].values
        interFolder3 = moodle.query(folder)[['3']].values
        interFolder4 = moodle.query(folder)[['4']].values
        interFolder5 = moodle.query(folder)[['5']].values
        interFolder6 = moodle.query(folder)[['6']].values
        interFolder7 = moodle.query(folder)[['7']].values
        
        interForum0 = moodle.query(forum)[['0']].values
        interForum1 = moodle.query(forum)[['1']].values
        interForum2 = moodle.query(forum)[['2']].values
        interForum3 = moodle.query(forum)[['3']].values
        interForum4 = moodle.query(forum)[['4']].values
        interForum5 = moodle.query(forum)[['5']].values
        interForum6 = moodle.query(forum)[['6']].values
        interForum7 = moodle.query(forum)[['7']].values
        
        interPage0 = moodle.query(page)[['0']].values
        interPage1 = moodle.query(page)[['1']].values
        interPage2 = moodle.query(page)[['2']].values
        interPage3 = moodle.query(page)[['3']].values
        interPage4 = moodle.query(page)[['4']].values
        interPage5 = moodle.query(page)[['5']].values
        interPage6 = moodle.query(page)[['6']].values
        interPage7 = moodle.query(page)[['7']].values
        
        interQuiz0 = moodle.query(quiz)[['0']].values
        interQuiz1 = moodle.query(quiz)[['1']].values
        interQuiz2 = moodle.query(quiz)[['2']].values
        interQuiz3 = moodle.query(quiz)[['3']].values
        interQuiz4 = moodle.query(quiz)[['4']].values
        interQuiz5 = moodle.query(quiz)[['5']].values
        interQuiz6 = moodle.query(quiz)[['6']].values
        interQuiz7 = moodle.query(quiz)[['7']].values
    
        interURL0 = moodle.query(url)[['0']].values      
        interURL1 = moodle.query(url)[['1']].values
        interURL2 = moodle.query(url)[['2']].values
        interURL3 = moodle.query(url)[['3']].values
        interURL4 = moodle.query(url)[['4']].values
        interURL5 = moodle.query(url)[['5']].values
        interURL6 = moodle.query(url)[['6']].values
        interURL7 = moodle.query(url)[['7']].values
        
        interFolder0 = str(interFolder0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder1 = str(interFolder1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder2 = str(interFolder2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder3 = str(interFolder3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder4 = str(interFolder4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder5 = str(interFolder5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder6 = str(interFolder6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder7 = str(interFolder7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        interForum0 = str(interForum0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum1 = str(interForum1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum2 = str(interForum2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum3 = str(interForum3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum4 = str(interForum4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum5 = str(interForum5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum6 = str(interForum6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum7 = str(interForum7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        interPage0 = str(interPage0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage1 = str(interPage1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage2 = str(interPage2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage3 = str(interPage3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage4 = str(interPage4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage5 = str(interPage5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage6 = str(interPage6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage7 = str(interPage7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        interQuiz0 = str(interQuiz0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz1 = str(interQuiz1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz2 = str(interQuiz2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz3 = str(interQuiz3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz4 = str(interQuiz4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz5 = str(interQuiz5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz6 = str(interQuiz6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz7 = str(interQuiz7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        interURL0 = str(interURL0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL1 = str(interURL1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL2 = str(interURL2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL3 = str(interURL3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL4 = str(interURL4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL5 = str(interURL5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL6 = str(interURL6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL7 = str(interURL7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        #print(interFolder)
        #print(interForum)
        #print(interPage)
        #print(interQuiz)
        #print(interURL)
        resultadoxcenso.loc[index, 'Folder Week 2'] = interFolder0
        resultadoxcenso.loc[index, 'Folder Week 4'] = interFolder1
        resultadoxcenso.loc[index, 'Folder Week 6'] = interFolder2
        resultadoxcenso.loc[index, 'Folder Week 8'] = interFolder3
        resultadoxcenso.loc[index, 'Folder Week 10'] = interFolder4
        resultadoxcenso.loc[index, 'Folder Week 12'] = interFolder5
        resultadoxcenso.loc[index, 'Folder Week 14'] = interFolder6
        resultadoxcenso.loc[index, 'Folder Week 16'] = interFolder7
        
        resultadoxcenso.loc[index, 'Forum Week 2'] = interForum0
        resultadoxcenso.loc[index, 'Forum Week 4'] = interForum1
        resultadoxcenso.loc[index, 'Forum Week 6'] = interForum2
        resultadoxcenso.loc[index, 'Forum Week 8'] = interForum3
        resultadoxcenso.loc[index, 'Forum Week 10'] = interForum4
        resultadoxcenso.loc[index, 'Forum Week 12'] = interForum5
        resultadoxcenso.loc[index, 'Forum Week 14'] = interForum6
        resultadoxcenso.loc[index, 'Forum Week 16'] = interForum7
        
        resultadoxcenso.loc[index, 'Page Week 2'] = interPage0
        resultadoxcenso.loc[index, 'Page Week 4'] = interPage1
        resultadoxcenso.loc[index, 'Page Week 6'] = interPage2
        resultadoxcenso.loc[index, 'Page Week 8'] = interPage3
        resultadoxcenso.loc[index, 'Page Week 10'] = interPage4
        resultadoxcenso.loc[index, 'Page Week 12'] = interPage5
        resultadoxcenso.loc[index, 'Page Week 14'] = interPage6
        resultadoxcenso.loc[index, 'Page Week 16'] = interPage7
        
        resultadoxcenso.loc[index, 'Quiz Week 2'] = interQuiz0
        resultadoxcenso.loc[index, 'Quiz Week 4'] = interQuiz1
        resultadoxcenso.loc[index, 'Quiz Week 6'] = interQuiz2
        resultadoxcenso.loc[index, 'Quiz Week 8'] = interQuiz3
        resultadoxcenso.loc[index, 'Quiz Week 10'] = interQuiz4
        resultadoxcenso.loc[index, 'Quiz Week 12'] = interQuiz5
        resultadoxcenso.loc[index, 'Quiz Week 14'] = interQuiz6
        resultadoxcenso.loc[index, 'Quiz Week 16'] = interQuiz7
        
        resultadoxcenso.loc[index, 'URL Week 2'] = interURL0
        resultadoxcenso.loc[index, 'URL Week 4'] = interURL1
        resultadoxcenso.loc[index, 'URL Week 6'] = interURL2
        resultadoxcenso.loc[index, 'URL Week 8'] = interURL3
        resultadoxcenso.loc[index, 'URL Week 10'] = interURL4
        resultadoxcenso.loc[index, 'URL Week 12'] = interURL5
        resultadoxcenso.loc[index, 'URL Week 14'] = interURL6
        resultadoxcenso.loc[index, 'URL Week 16'] = interURL7
        
    #print(temp)
# Out:
# index = 14
# index = 303
# index = 343
# index = 823
# index = 869
# index = 1059
# index = 1217
# index = 1225
# index = 1249
# index = 1441
# index = 1844
# index = 1948
# index = 1971
# index = 2119
# index = 2174
# index = 2227
# index = 2268
# index = 2406
# index = 2411
# index = 2548
# index = 2621
# index = 2624
# index = 2676
# index = 2694
# index = 2745
# index = 2758
# index = 2903
# index = 3059
# index = 3085
# index = 3127
# index = 3136
# index = 3208
# index = 3238
# index = 3271
# index = 3306
# index = 3324
# index = 3339
# index = 3378
# index = 3445
# index = 3587
# index = 3631
# index = 3654
# index = 3749
# index = 3815
# index = 3822
# index = 4019
# index = 4093
# index = 4157
# index = 4213
# index = 4220
# index = 4353
# index = 4388
# index = 4510
# index = 4798
# index = 4971
# index = 5062
# index = 5713
# index = 5714
# index = 5750

# %%
for index, row in resultadoxcenso.iterrows():
    #id_moodle = row['Description']
    #temp = int(row['codigo_persona'])
    if int(row['codigo_mat']) == codDisciplina:
        print('index = ' + str(index) )
        
        #busca = "Description == '" + str(row['Id_moodle'])+ "' and Component = 'Folder'"
        folder = "Description == '" + str(row['Id_moodle'])+ "'" + " & Component == 'Folder'"
        forum = "Description == '" + str(row['Id_moodle'])+ "' & Component == 'Forum'"
        page = "Description == '" + str(row['Id_moodle'])+ "' & Component == 'Page'"
        quiz = "Description == '" + str(row['Id_moodle'])+ "' & Component == 'Quiz'"
        url = "Description == '" + str(row['Id_moodle'])+ "' & Component == 'URL'"
        #print(folder)
        interFolder0 = moodle.query(folder)[['0']].values
        interFolder1 = moodle.query(folder)[['1']].values
        interFolder2 = moodle.query(folder)[['2']].values
        interFolder3 = moodle.query(folder)[['3']].values
        interFolder4 = moodle.query(folder)[['4']].values
        interFolder5 = moodle.query(folder)[['5']].values
        interFolder6 = moodle.query(folder)[['6']].values
        interFolder7 = moodle.query(folder)[['7']].values
        
        interForum0 = moodle.query(forum)[['0']].values
        interForum1 = moodle.query(forum)[['1']].values
        interForum2 = moodle.query(forum)[['2']].values
        interForum3 = moodle.query(forum)[['3']].values
        interForum4 = moodle.query(forum)[['4']].values
        interForum5 = moodle.query(forum)[['5']].values
        interForum6 = moodle.query(forum)[['6']].values
        interForum7 = moodle.query(forum)[['7']].values
        
        interPage0 = moodle.query(page)[['0']].values
        interPage1 = moodle.query(page)[['1']].values
        interPage2 = moodle.query(page)[['2']].values
        interPage3 = moodle.query(page)[['3']].values
        interPage4 = moodle.query(page)[['4']].values
        interPage5 = moodle.query(page)[['5']].values
        interPage6 = moodle.query(page)[['6']].values
        interPage7 = moodle.query(page)[['7']].values
        
        interQuiz0 = moodle.query(quiz)[['0']].values
        interQuiz1 = moodle.query(quiz)[['1']].values
        interQuiz2 = moodle.query(quiz)[['2']].values
        interQuiz3 = moodle.query(quiz)[['3']].values
        interQuiz4 = moodle.query(quiz)[['4']].values
        interQuiz5 = moodle.query(quiz)[['5']].values
        interQuiz6 = moodle.query(quiz)[['6']].values
        interQuiz7 = moodle.query(quiz)[['7']].values
    
        interURL0 = moodle.query(url)[['0']].values      
        interURL1 = moodle.query(url)[['1']].values
        interURL2 = moodle.query(url)[['2']].values
        interURL3 = moodle.query(url)[['3']].values
        interURL4 = moodle.query(url)[['4']].values
        interURL5 = moodle.query(url)[['5']].values
        interURL6 = moodle.query(url)[['6']].values
        interURL7 = moodle.query(url)[['7']].values
        
        interFolder0 = str(interFolder0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder1 = str(interFolder1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder2 = str(interFolder2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder3 = str(interFolder3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder4 = str(interFolder4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder5 = str(interFolder5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder6 = str(interFolder6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interFolder7 = str(interFolder7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        interForum0 = str(interForum0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum1 = str(interForum1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum2 = str(interForum2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum3 = str(interForum3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum4 = str(interForum4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum5 = str(interForum5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum6 = str(interForum6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interForum7 = str(interForum7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        interPage0 = str(interPage0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage1 = str(interPage1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage2 = str(interPage2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage3 = str(interPage3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage4 = str(interPage4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage5 = str(interPage5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage6 = str(interPage6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interPage7 = str(interPage7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        interQuiz0 = str(interQuiz0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz1 = str(interQuiz1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz2 = str(interQuiz2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz3 = str(interQuiz3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz4 = str(interQuiz4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz5 = str(interQuiz5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz6 = str(interQuiz6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interQuiz7 = str(interQuiz7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        interURL0 = str(interURL0).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL1 = str(interURL1).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL2 = str(interURL2).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL3 = str(interURL3).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL4 = str(interURL4).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL5 = str(interURL5).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL6 = str(interURL6).replace(' ','').replace("'",'').replace('[','').replace(']','')
        interURL7 = str(interURL7).replace(' ','').replace("'",'').replace('[','').replace(']','')
        
        #print(interFolder)
        #print(interForum)
        #print(interPage)
        #print(interQuiz)
        #print(interURL)
        resultadoxcenso.loc[index, 'Folder Week 2'] = interFolder0
        resultadoxcenso.loc[index, 'Folder Week 4'] = interFolder1
        resultadoxcenso.loc[index, 'Folder Week 6'] = interFolder2
        resultadoxcenso.loc[index, 'Folder Week 8'] = interFolder3
        resultadoxcenso.loc[index, 'Folder Week 10'] = interFolder4
        resultadoxcenso.loc[index, 'Folder Week 12'] = interFolder5
        resultadoxcenso.loc[index, 'Folder Week 14'] = interFolder6
        resultadoxcenso.loc[index, 'Folder Week 16'] = interFolder7
        
        resultadoxcenso.loc[index, 'Forum Week 2'] = interForum0
        resultadoxcenso.loc[index, 'Forum Week 4'] = interForum1
        resultadoxcenso.loc[index, 'Forum Week 6'] = interForum2
        resultadoxcenso.loc[index, 'Forum Week 8'] = interForum3
        resultadoxcenso.loc[index, 'Forum Week 10'] = interForum4
        resultadoxcenso.loc[index, 'Forum Week 12'] = interForum5
        resultadoxcenso.loc[index, 'Forum Week 14'] = interForum6
        resultadoxcenso.loc[index, 'Forum Week 16'] = interForum7
        
        resultadoxcenso.loc[index, 'Page Week 2'] = interPage0
        resultadoxcenso.loc[index, 'Page Week 4'] = interPage1
        resultadoxcenso.loc[index, 'Page Week 6'] = interPage2
        resultadoxcenso.loc[index, 'Page Week 8'] = interPage3
        resultadoxcenso.loc[index, 'Page Week 10'] = interPage4
        resultadoxcenso.loc[index, 'Page Week 12'] = interPage5
        resultadoxcenso.loc[index, 'Page Week 14'] = interPage6
        resultadoxcenso.loc[index, 'Page Week 16'] = interPage7
        
        resultadoxcenso.loc[index, 'Quiz Week 2'] = interQuiz0
        resultadoxcenso.loc[index, 'Quiz Week 4'] = interQuiz1
        resultadoxcenso.loc[index, 'Quiz Week 6'] = interQuiz2
        resultadoxcenso.loc[index, 'Quiz Week 8'] = interQuiz3
        resultadoxcenso.loc[index, 'Quiz Week 10'] = interQuiz4
        resultadoxcenso.loc[index, 'Quiz Week 12'] = interQuiz5
        resultadoxcenso.loc[index, 'Quiz Week 14'] = interQuiz6
        resultadoxcenso.loc[index, 'Quiz Week 16'] = interQuiz7
        
        resultadoxcenso.loc[index, 'URL Week 2'] = interURL0
        resultadoxcenso.loc[index, 'URL Week 4'] = interURL1
        resultadoxcenso.loc[index, 'URL Week 6'] = interURL2
        resultadoxcenso.loc[index, 'URL Week 8'] = interURL3
        resultadoxcenso.loc[index, 'URL Week 10'] = interURL4
        resultadoxcenso.loc[index, 'URL Week 12'] = interURL5
        resultadoxcenso.loc[index, 'URL Week 14'] = interURL6
        resultadoxcenso.loc[index, 'URL Week 16'] = interURL7
        
    #print(temp)
# Out:
# index = 14
# index = 303
# index = 343
# index = 823
# index = 869
# index = 1059
# index = 1217
# index = 1225
# index = 1249
# index = 1441
# index = 1844
# index = 1948
# index = 1971
# index = 2119
# index = 2174
# index = 2227
# index = 2268
# index = 2406
# index = 2411
# index = 2548
# index = 2621
# index = 2624
# index = 2676
# index = 2694
# index = 2745
# index = 2758
# index = 2903
# index = 3059
# index = 3085
# index = 3127
# index = 3136
# index = 3208
# index = 3238
# index = 3271
# index = 3306
# index = 3324
# index = 3339
# index = 3378
# index = 3445
# index = 3587
# index = 3631
# index = 3654
# index = 3749
# index = 3815
# index = 3822
# index = 4019
# index = 4093
# index = 4157
# index = 4213
# index = 4220
# index = 4353
# index = 4388
# index = 4510
# index = 4798
# index = 4971
# index = 5062
# index = 5713
# index = 5714
# index = 5750

# %%
resultadoxcenso.to_csv('Documentos/UDELAR/6.0_RESULTADOxCENSO_varsNovo.csv', header=True)
